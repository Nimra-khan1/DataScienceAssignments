# %%
# !pip install nltk scikit-learn

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from sklearn.feature_extraction.text import TfidfVectorizer
import pandas as pd
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
from google.colab import files
uploaded = files.upload()

df = pd.read_csv(list(uploaded.keys())[0])
df.head()
# Out:
#      <input type="file" id="files-d9ab74e7-32f9-4173-ad86-5c83d7d65029" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d9ab74e7-32f9-4173-ad86-5c83d7d65029">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data = {
    'text': [
        "Artificial intelligence is transforming industries.",
        "NLP helps computers understand human language.",
        "Deep learning models perform well on text data."
    ]
}
df = pd.DataFrame(data)
df
# Out:
#                                                 text
# 0  Artificial intelligence is transforming indust...
# 1     NLP helps computers understand human language.
# 2    Deep learning models perform well on text data.

# %%
import nltk
nltk.download('punkt_tab')
def tokenize(text):
    return word_tokenize(text.lower())

df['tokens'] = df['text'].apply(tokenize)
df
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
#                                                 text  \
# 0  Artificial intelligence is transforming indust...
# 1     NLP helps computers understand human language.
# 2    Deep learning models perform well on text data.
#
#                                               tokens
# 0  [artificial, intelligence, is, transforming, i...
# 1  [nlp, helps, computers, understand, human, lan...
# 2  [deep, learning, models, perform, well, on, te...

# %%
def tokenize(text):
    return word_tokenize(text.lower())

df['tokens'] = df['text'].apply(tokenize)
df
# Out:
#                                                 text  \
# 0  Artificial intelligence is transforming indust...
# 1     NLP helps computers understand human language.
# 2    Deep learning models perform well on text data.
#
#                                               tokens
# 0  [artificial, intelligence, is, transforming, i...
# 1  [nlp, helps, computers, understand, human, lan...
# 2  [deep, learning, models, perform, well, on, te...

# %%
stop_words = set(stopwords.words('english'))

def remove_stopwords(tokens):
    return [word for word in tokens if word not in stop_words]

df['clean_tokens'] = df['tokens'].apply(remove_stopwords)
df
# Out:
#                                                 text  \
# 0  Artificial intelligence is transforming indust...
# 1     NLP helps computers understand human language.
# 2    Deep learning models perform well on text data.
#
#                                               tokens  \
# 0  [artificial, intelligence, is, transforming, i...
# 1  [nlp, helps, computers, understand, human, lan...
# 2  [deep, learning, models, perform, well, on, te...
#
#                                         clean_tokens
# 0  [artificial, intelligence, transforming, indus...
# 1  [nlp, helps, computers, understand, human, lan...
# 2  [deep, learning, models, perform, well, text, ...

# %%
corpus = df['text'].tolist()

vectorizer = TfidfVectorizer(stop_words='english')
tfidf_matrix = vectorizer.fit_transform(corpus)

tfidf_df = pd.DataFrame(
    tfidf_matrix.toarray(),
    columns=vectorizer.get_feature_names_out()
)
tfidf_df
# Out:
#    artificial  computers      data      deep     helps     human  industries  \
# 0         0.5   0.000000  0.000000  0.000000  0.000000  0.000000         0.5
# 1         0.0   0.408248  0.000000  0.000000  0.408248  0.408248         0.0
# 2         0.0   0.000000  0.408248  0.408248  0.000000  0.000000         0.0
#
#    intelligence  language  learning    models       nlp   perform      text  \
# 0           0.5  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1           0.0  0.408248  0.000000  0.000000  0.408248  0.000000  0.000000
# 2           0.0  0.000000  0.408248  0.408248  0.000000  0.408248  0.408248
#
#    transforming  understand
# 0           0.5    0.000000
# 1           0.0    0.408248
# 2           0.0    0.000000

# %%
tfidf_df
# Out:
#    artificial  computers      data      deep     helps     human  industries  \
# 0         0.5   0.000000  0.000000  0.000000  0.000000  0.000000         0.5
# 1         0.0   0.408248  0.000000  0.000000  0.408248  0.408248         0.0
# 2         0.0   0.000000  0.408248  0.408248  0.000000  0.000000         0.0
#
#    intelligence  language  learning    models       nlp   perform      text  \
# 0           0.5  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1           0.0  0.408248  0.000000  0.000000  0.408248  0.000000  0.000000
# 2           0.0  0.000000  0.408248  0.408248  0.000000  0.408248  0.408248
#
#    transforming  understand
# 0           0.5    0.000000
# 1           0.0    0.408248
# 2           0.0    0.000000

# %% [markdown]
# 🧾 Project Milestone
#
# “The NLP preprocessing pipeline has been successfully implemented. The text dataset was processed using tokenization, stopword removal, and TF-IDF vectorization. The final TF-IDF matrix is ready and will now be used for model training in the next milestone.”
#
# 🪞 Reflection
#
# “In this assignment, I learned how to apply core NLP preprocessing steps. Tokenization helped in breaking sentences into words. Stopword removal improved the quality of text by removing unnecessary words. TF-IDF converted the text into numerical features which can be used for machine learning models. This preprocessing step is essential for any text-based project.”
